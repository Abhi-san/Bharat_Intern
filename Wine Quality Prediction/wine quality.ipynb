# %%
import pandas as pd

df = pd.read_csv('Wine_Dataset.csv')
df.sample()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 773            7.9               0.4         0.29             1.8      0.157
#
#      free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 773                  1.0                  44.0   0.9973  3.3       0.92
#
#      alcohol  quality
# 773      9.5        6

# %%
df = df.rename(columns={'fixed acidity': 'Fixed Acidity', 'volatile acidity': 'Volatile Acidity', 'citric acid': 'Citric Acid',
                        'residual sugar': 'Residual Sugar', 'chlorides': 'Chlorides', 'free sulfur dioxide': 'Free Sulfur Dioxide', 'total sulfur dioxide':'Total Sulfur Dioxide',
                        'density': 'Density', 'pH': 'pH', 'sulphates': 'Sulphates', 'alcohol': 'Alcohol', 'quality': 'Quality'})
df
# Out:
#       Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fixed Acidity         1599 non-null   float64
#  1   Volatile Acidity      1599 non-null   float64
#  2   Citric Acid           1599 non-null   float64
#  3   Residual Sugar        1599 non-null   float64
#  4   Chlorides             1599 non-null   float64
#  5   Free Sulfur Dioxide   1599 non-null   float64
#  6   Total Sulfur Dioxide  1599 non-null   float64
#  7   Density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   Sulphates             1599 non-null   float64
#  10  Alcohol               1599 non-null   float64
#  11  Quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.isnull().any()
# Out:
# Fixed Acidity           False
# Volatile Acidity        False
# Citric Acid             False
# Residual Sugar          False
# Chlorides               False
# Free Sulfur Dioxide     False
# Total Sulfur Dioxide    False
# Density                 False
# pH                      False
# Sulphates               False
# Alcohol                 False
# Quality                 False
# dtype: bool

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# Fixed Acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# Volatile Acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# Citric Acid           1599.0   0.270976   0.194801  0.00000   0.0900
# Residual Sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# Chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# Free Sulfur Dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# Total Sulfur Dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# Density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# Sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# Alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# Quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
import matplotlib.pyplot as plt

plt.bar(df['Quality'], df['Alcohol'])
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap="cividis", annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split

x = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

regr = LinearRegression()
regr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
abhi = regr.predict([[5, 0.01, 0, 15, 0.001, 30, 50, 0.95, 3, 0.9, 18]])

def map_to_category(output):
    if output >= 8:
        return "Excellent"
    elif output < 8:
        return "Good"
    elif output <= 4:
        return "Reasonable"
    else:
        return "Inaccurate"
        
category = map_to_category(abhi)
print(f"Regression Output: {abhi[0]}")
print(f"Category: {category}")
# Out:
# Regression Output: 10.499143135261093
# Category: Excellent

# %%
abhi = regr.predict([[5, 0.1, 0.2, 8, 0.01, 10, 60, 0.98, 3.5, 0.6, 10]])

def map_to_category(output):
    if output >= 8:
        return "Excellent"
    elif output < 8:
        return "Good"
    elif output <= 4:
        return "Reasonable"
    else:
        return "Inaccurate"
        
category = map_to_category(abhi)
print(f"Regression Output: {abhi[0]}")
print(f"Category: {category}")
# Out:
# Regression Output: 6.574367786454868
# Category: Good

# %%
abhi = regr.predict([[8, 0.3, 0.8, 4, 0.51, 2.6, 9, 0.98, 3.5, 0.7, 4]])

def map_to_category(output):
    if output >= 8:
        return "Excellent"
    elif 4 <= output < 8:
        return "Good"
    elif 2 <= output < 4:
        return "Reasonable"
    else:
        return "Inaccurate"
        
category = map_to_category(abhi)
print(f"Regression Output: {abhi[0]}")
print(f"Category: {category}")
# Out:
# Regression Output: 3.9207851019995204
# Category: Reasonable

# %%
abhi = regr.predict([[6, 0.13, 12, 4, 0.8, 2.6, 9, 0.98, 3.5, 1, 3]])
def map_to_category(output):
    if output >= 8:
        return "Excellent"
    elif 4 <= outpuXt < 8:
        return "Good"
    elif 2 <= output < 4:
        return "Reasonable"
    else:
        return "Inaccurate"
        
category = map_to_category(abhi)
print(f"Regression Output: {abhi[0]}")
print(f"Category: {category}")
# Out:
# Regression Output: 1.5069812114454066
# Category: Inaccurate
